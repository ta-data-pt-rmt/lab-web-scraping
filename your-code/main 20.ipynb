# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'
response = requests.get(url)
response.content
# Out:
# b'\n\n<!DOCTYPE html>\n<html lang="en" class=" no-js" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark"  data-a11y-animated-images="system" data-a11y-link-underlines="true">\n\n\n\n\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  \n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-38f1bf52eeeb.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-56010aa53a8f.css" /><link data-color-theme="dark_dimmed" cross
# ...

# %% [markdown]
# #### 1. Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools or clicking in 'Inspect' on any browser. Here is an example:
#
# ![title](example_1.png)
#
# 2. Use BeautifulSoup `find_all()` to extract all the html elements that contain the developer names. Hint: pass in the `attrs` parameter to specify the class.
#
# 3. Loop through the elements found and get the text for each of them.
#
# 4. While you are at it, use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names. Hint: you may also use `.get_text()` instead of `.text` and pass in the desired parameters to do some string manipulation (check the documentation).
#
# 5. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
url = 'https://github.com/trending/developers'
response = requests.get(url)


soup = BeautifulSoup(response.content, 'html.parser')
developer_elements = soup.find_all('h1', class_='h3 lh-condensed')

for element in developer_elements:
    name_text = element.get_text(strip=True, separator=' ')
    print(name_text)
# Out:
# Ismail Pelaseyed
# oobabooga
# James Newton-King
# Alexey Milovidov
# Paul Wieland
# Naman Goel
# pilcrow
# Leonid Bugaev
# Mark Tyneway
# Engin Diri
# Saúl Ibarra Corretgé
# Ben McCann
# Toby Mao
# Andreas Thomas
# Emil Ernerfeldt
# Ryan Levick
# Will Jones
# Carlos Scheidegger
# lllyasviel
# Steve Purcell
# Matthias Fey
# Nick Raienko
# Steven Luscher
# Rui Chen
# Avik Pal

# %% [markdown]
# #### 1.1. Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/python?since=daily'

# %%
response = requests.get(url)
response.content
soup = BeautifulSoup(response.content)
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" data-a11y-animated-images="system" data-a11y-link-underlines="true" data-color-mode="auto" data-dark-theme="dark" data-light-theme="light" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://github.githubassets.com" rel="dns-prefetch"/>
#   <link href="https://avatars.githubusercontent.com" rel="dns-prefetch"/>
#   <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
#   <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
#   <link crossorigin="" href="https://github.githubassets.com" rel="preconnect"/>
#   <link href="https://avatars.githubusercontent.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/light-38f1bf52eeeb.css" media="all" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="https://github.githubassets.com/assets/dark-56010aa53a8f.css" media="all" rel="stylesheet"/>
# ...

# %%
links = soup.find_all('a', href=True)

for link in links:
    url = 'https://github.githubassets.com' + link['href']
    print(url)
# Out:
# https://github.githubassets.com#start-of-content
# https://github.githubassets.comhttps://github.com/
# https://github.githubassets.com/signup?ref_cta=Sign+up&ref_loc=header+logged+out&ref_page=%2Ftrending%2Fpython&source=header
# https://github.githubassets.com/features/actions
# https://github.githubassets.com/features/packages
# https://github.githubassets.com/features/security
# https://github.githubassets.com/features/codespaces
# https://github.githubassets.com/features/copilot
# https://github.githubassets.com/features/code-review
# https://github.githubassets.com/features/issues
# https://github.githubassets.com/features/discussions
# https://github.githubassets.com/features
# https://github.githubassets.comhttps://docs.github.com
# https://github.githubassets.comhttps://skills.github.com/
# https://github.githubassets.comhttps://github.blog
# https://github.githubassets.com/enterprise
# https://github.githubassets.com/team
# ...

# %% [markdown]
# #### 2. Display all the image links from Walt Disney wikipedia page.
# Hint: use `.get()` to access information inside tags. Check out the documentation.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/Walt_Disney'

# %%
response = requests.get(url)
response.content
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Walt Disney - Wikipedia
#   </title>
#   <script>
# ...

# %%
img_tags = soup.find_all('img')

for img_tag in img_tags:
    src = img_tag.get('src')
    print(src)
# Out:
# /static/images/icons/wikipedia.png
# /static/images/mobile/copyright/wikipedia-wordmark-en.svg
# /static/images/mobile/copyright/wikipedia-tagline-en.svg
# //upload.wikimedia.org/wikipedia/en/thumb/e/e7/Cscr-featured.svg/20px-Cscr-featured.svg.png
# //upload.wikimedia.org/wikipedia/en/thumb/8/8c/Extended-protection-shackle.svg/20px-Extended-protection-shackle.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/d/df/Walt_Disney_1946.JPG/220px-Walt_Disney_1946.JPG
# //upload.wikimedia.org/wikipedia/commons/thumb/8/87/Walt_Disney_1942_signature.svg/150px-Walt_Disney_1942_signature.svg.png
# //upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg/220px-Walt_Disney_Birthplace_Exterior_Hermosa_Chicago_Illinois.jpg
# //upload.wikimedia.org/wikipedia/commons/thumb/c/c4/Walt_Disney_envelope_ca._1921.jpg/220px-Walt_Disney_envelope_ca._1921.jpg
# ...

# %% [markdown]
# #### 2.1. List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.wikipedia.org/'

# %%
response = requests.get(url)
response.content
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Walt Disney - Wikipedia
#   </title>
#   <script>
# ...

# %%
paragraphs = soup.find_all('p')
text = '\n'.join([paragraph.get_text(strip=True) 
for paragraph in paragraphs])
print(text)
# Out:
# Walter Elias Disney(/ˈdɪzni/;[2]December 5, 1901 –  December 15, 1966) was an American animator, film producer, and entrepreneur. A pioneer of theAmerican animation industry, he introduced several developments in the production ofcartoons. As a film producer, he holds the record for mostAcademy Awardsearned and nominations by an individual. He was presented with twoGolden GlobeSpecial Achievement Awards and anEmmy Award, among other honors. Several of his films are included in theNational Film Registryby theLibrary of Congressand have also been named as some of thegreatest films everby theAmerican Film Institute.
# ...

# %%
languages = soup.find_all('div class="central-featured-lang lang1" lang="en" dir="ltr")

languages_names = []

for i in languages:
    name = language.get_text()
    languages_names.append(name) 

languages_names
# Out:
#   File "/var/folders/q5/5zcd6_2115553r1tvx9_1vk40000gn/T/ipykernel_82284/2914354345.py", line 1
#     languages = soup.find_all('div class="central-featured-lang lang1" lang="en" dir="ltr")
#                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# #### 2.2. Display the top 10 languages by number of native speakers stored in a pandas dataframe.
# Hint: After finding the correct table you want to analyse, you can use a nested **for** loop to find the elements row by row (check out the 'td' and 'tr' tags). <br>An easier way to do it is using pd.read_html(), check out documentation [here](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.read_html.html).

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# language_container = soup.find('div', {'class="search-container'})

# language_list = []



# soup = BeautifulSoup(response.content, 'html.parser')

# # Find the div with the specified class, lang, and dir attributes
# languages_div = soup.find('div', {'class': 'central-featured-lang lang1', 'lang': 'en', 'dir': 'ltr'})

# # Find all the language names within the specified div
# languages_names = [language.get_text(strip=True) for language in languages_div.find_all('strong')]

# print(languages_names)




language_container = soup.find('div', {'class="search-container'})

language_list = []
soup = BeautifulSoup(response.content, 'html.parser')
languages_div = soup.find('a', {'class'='vector-toc-link', href=''#Top_languages_by_population'})
languages_names = [language.get_text(strip=True) for language in languages_div.find_all('strong')]

print(languages_names)
# Out:
#   File "/var/folders/q5/5zcd6_2115553r1tvx9_1vk40000gn/T/ipykernel_82284/856123549.py", line 24
#     languages_div = soup.find('a', {'class'='vector-toc-link', href=''#Top_languages_by_population'})
#                                            ^
# SyntaxError: invalid syntax

# %%
# import requests
# from bs4 import BeautifulSoup

# url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# response = requests.get(url)

# soup = BeautifulSoup(response.content, 'html.parser')

# language_container = soup.find('div', class_='search-container')

# languages_div = soup.find('a', class_='vector-toc-link', href='#Top_languages_by_population')
# languages_names = [language.get_text(strip=True) for language in languages_div.find_all('strong')]

# print(languages_names)
# Out:
# []

# %% [markdown]
# #### 3. Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.
# Hint: If you hover over the title of the movie, you should see the director's name. Can you find where it's stored in the html?

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### 3.1. Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'https://www.imdb.com/list/ls009796553/'

# %%
# your code here

# %% [markdown]
# ## Bonus

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here

# %% [markdown]
# ####  Display the 100 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.
# ***Hint:*** Here the displayed number of earthquakes per page is 20, but you can easily move to the next page by looping through the desired number of pages and adding it to the end of the url.

# %%
# This is the url you will scrape in this exercise
url = 'https://www.emsc-csem.org/Earthquake/?view='

# This is how you will loop through each page:
number_of_pages = int(100/20)
each_page_urls = []

for n in range(1, number_of_pages+1):
    link = url+str(n)
    each_page_urls.append(link)
    
each_page_urls

# %%
# your code here
